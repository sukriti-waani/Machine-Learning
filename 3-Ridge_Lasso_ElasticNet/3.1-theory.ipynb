# %% [markdown]
# # 📘 Ridge, Lasso and ElasticNet Regression
# (Regularization Techniques in Linear Regression)
#
# ## 1️⃣ Why Regularization is Needed?
#
# In Linear Regression:
#
# h(x) = θ₀ + θ₁x₁ + θ₂x₂ + ... + θₙxₙ
#
# Cost Function:
#
# J(θ) = (1 / 2m) Σᵢ₌₁ᵐ ( h(x⁽ⁱ⁾) − y⁽ⁱ⁾ )²
#
# Problem:
# - High training accuracy
# - Low testing accuracy
#
# This means **Overfitting**
# → Low bias, High variance
#
#
# ## 2️⃣ Ridge Regression (L2 Regularization)
#
# Ridge Regression reduces **overfitting** by penalizing large coefficients.
#
# Cost Function:
#
# J(θ) = (1 / 2m) Σ ( h(x⁽ⁱ⁾) − y⁽ⁱ⁾ )² + λ Σ θⱼ²
#
#
# ### Key Points of Ridge
#
# - Adds **squared slope term**
# - λ (lambda) is a **hyperparameter**
# - λ = 0 → Normal Linear Regression
# - λ ↑ → Slopes become smaller
# - Coefficients never become exactly zero
#
#
# ## 3️⃣ Lasso Regression (L1 Regularization)
#
# Lasso adds **absolute value of coefficients**.
#
# Cost Function:
#
# J(θ) = (1 / 2m) Σ ( h(x⁽ⁱ⁾) − y⁽ⁱ⁾ )² + λ Σ |θⱼ|
#
#
# ### Key Points of Lasso
#
# - Performs **Feature Selection**
# - Some coefficients become exactly **0**
# - Removes useless features
# - Helps simplify model
#
#
# ## 4️⃣ ElasticNet Regression
#
# ElasticNet is a combination of **Ridge + Lasso**.
#
# Cost Function:
#
# J(θ) = (1 / 2m) Σ ( h(x⁽ⁱ⁾) − y⁽ⁱ⁾ )²
#        + λ₁ Σ θⱼ²
#        + λ₂ Σ |θⱼ|
#
#
# ### Key Points of ElasticNet
#
# - Reduces Overfitting (Ridge part)
# - Performs Feature Selection (Lasso part)
# - Works well when many correlated features exist
#
#
# ## 5️⃣ Effect of Lambda (λ)
#
# - λ = 0 → No regularization
# - λ ↑ → Model becomes simpler
# - Very high λ → Underfitting
#
#
# ## 6️⃣ Ridge vs Lasso vs ElasticNet
#
# Ridge:
# - Shrinks coefficients
# - No feature elimination
#
# Lasso:
# - Shrinks + removes features
# - Best for feature selection
#
# ElasticNet:
# - Combines Ridge + Lasso
# - Best overall choice
#
#
# ## 7️⃣ Summary
#
# - Ridge uses L2 penalty
# - Lasso uses L1 penalty
# - ElasticNet uses both
# - Regularization prevents overfitting
# - Lambda controls penalty strength
