# %% [markdown]
# # 📘 Variants of Naïve Bayes
#
# Naïve Bayes has different variants depending on the **type of data** (features) used.
#
# ---
#
# ## 🔹 Main Variants of Naïve Bayes
#
# 1. Bernoulli Naïve Bayes
# 2. Multinomial Naïve Bayes
# 3. Gaussian Naïve Bayes
#
# ---
#
# ## 1️⃣ Bernoulli Naïve Bayes
#
# ### 🔸 When to use?
# Bernoulli Naïve Bayes is used when **features follow Bernoulli distribution**.
#
# Bernoulli distribution means:
# - Feature values are **binary**
# - Possible values → `0 or 1` (Yes/No, True/False)
#
# ---
#
# ### 🔸 Example Dataset
#
# | f1  | f2   | f3     | Output |
# |----|------|--------|--------|
# | Yes | Pass | Male   | Yes    |
# | Yes | Fail | Female | No     |
# | No  | Pass | Male   | Yes    |
# | Yes | Fail | Female | No     |
#
# Here:
# - Features are binary (Yes/No)
# - Hence **Bernoulli Naïve Bayes** is suitable
#
# ---
#
# ### 🔸 Key Point
# - Input data must be **binary**
# - Used in simple classification problems
#
# ---
#
# ## 2️⃣ Multinomial Naïve Bayes
#
# ### 🔸 When to use?
# Multinomial Naïve Bayes is used when:
# - Input data is **text-based**
# - Features represent **frequency or count**
#
# ---
#
# ### 🔸 Common Use Case
# **Spam Classification**
#
# - Input → Email body (text)
# - Output → Spam / Not Spam (Ham)
#
# Example:
# - "You have won million dollar lottery" → Spam
# - "KRISH you have done good job" → Ham
#
# ---
#
# ### 🔸 Text to Numerical Conversion
#
# Text data must be converted into numbers using **NLP techniques**:
#
# 1. Bag of Words (BoW)
# 2. TF-IDF
# 3. Word2Vec
#
# After conversion, Multinomial Naïve Bayes is applied.
#
# ---
#
# ### 🔸 Key Point
# - Best for **text classification**
# - Works on **word counts or frequencies**
#
# ---
#
# ## 3️⃣ Gaussian Naïve Bayes
#
# ### 🔸 When to use?
# Gaussian Naïve Bayes is used when:
# - Features are **continuous**
# - Data follows **Gaussian (Normal) distribution**
#
# ---
#
# ### 🔸 Example Dataset
#
# | Age | Height | Weight | Output |
# |----|--------|--------|--------|
# | 25 | 170 | 78 | Yes |
# | 38 | 160 | 75 | No |
# | 22 | 150 | 80 | Yes |
# | 29 | 170 | 35 | No |
#
# This type of data is **continuous**, so Gaussian NB is used.
#
# ---
#
# ### 🔸 Gaussian Probability Formula (Normal Form)
#
# Probability of feature x given class y:
#
# P(x | y) = (1 / sqrt(2 * pi * sigma²)) * exp( - (x − mean)² / (2 * sigma²) )
#
# Where:
# - mean → average value of feature
# - sigma → standard deviation
#
# ---
#
# ### 🔸 Example Dataset
# - Iris Dataset
# - Medical data
# - Height, weight, age based predictions
#
# ---
#
# ## 🧠 Comparison Summary
#
# | Variant | Data Type | Example |
# |------|----------|--------|
# | Bernoulli NB | Binary (0/1) | Yes/No data |
# | Multinomial NB | Text / Count | Spam detection |
# | Gaussian NB | Continuous | Iris dataset |
#
# ---
#
# ## 📝 Summary
#
# - Naïve Bayes has **three main variants**
# - Choice depends on **type of input data**
# - Bernoulli → Binary data
# - Multinomial → Text data
# - Gaussian → Continuous data
