# %% [markdown]
# # 📘 Support Vector Machines (SVM)
#
# ---
#
# ## 1️⃣ What is Support Vector Machine?
#
# Support Vector Machine (SVM) is a **supervised machine learning algorithm** used for:
#
# - Classification → **SVC (Support Vector Classifier)**
# - Regression → **SVR (Support Vector Regressor)**
#
# It separates data using the **best possible decision boundary**.
#
# ---
#
# ## 2️⃣ Hyperplane
#
# A **hyperplane** is a line (2D) or plane (3D) that separates data points.
#
# Equation of hyperplane:
#
# w₁x₁ + w₂x₂ + b = 0
# or
# wᵀx + b = 0
#
# ---
#
# ## 3️⃣ Support Vectors
#
# Support vectors are the **closest data points to the hyperplane**.
#
# These points decide the position and direction of the hyperplane.
#
# ---
#
# ## 4️⃣ Margin
#
# Margin is the **distance between the two closest class boundaries**.
#
# Goal of SVM:
# Maximize the margin.
#
# Margin formula:
#
# Distance = 2 / ||w||
#
# ---
#
# ## 5️⃣ Hard Margin vs Soft Margin
#
# ### 🔹 Hard Margin
#
# - No misclassification allowed.
# - Works only if data is perfectly separable.
#
# ### 🔹 Soft Margin
#
# - Allows some misclassifications.
# - Used for real-world noisy data.
#
# ---
#
# ## 6️⃣ SVM Constraints
#
# For each data point:
#
# If yᵢ = +1
# wᵀx + b ≥ +1
#
# If yᵢ = -1
# wᵀx + b ≤ -1
#
# Combined constraint:
#
# yᵢ (wᵀx + b) ≥ 1
#
# ---
#
# ## 7️⃣ Cost Function of SVM
#
# We minimize:
#
# ||w||² / 2 + C Σ ξᵢ
#
# Where:
#
# - ||w||² / 2 → controls margin size
# - ξᵢ → hinge loss
# - C → penalty parameter (controls misclassification)
#
# ---
#
# ## 8️⃣ Hinge Loss
#
# Hinge loss measures **how far incorrect points are from the margin**.
#
# Loss = max(0, 1 − yᵢ (wᵀx + b))
#
# ---
#
# ## 9️⃣ Important Points
#
# | Term | Meaning |
# |------|---------|
# | w | Weight vector |
# | b | Bias |
# | Margin | Distance between support vectors |
# | C | Regularization parameter |
# | ξᵢ | Misclassification error |
#
# ---
#
# ## 🔚 Exam Summary
#
# - SVM finds the **optimal hyperplane**.
# - Uses **support vectors**.
# - Objective is to **maximize margin**.
# - Uses **hinge loss** in soft margin.
# - Works well for high-dimensional data.
