# %% [markdown]
# # 📘 Support Vector Machine – Kernels
#
# ## 1️⃣ What is a Kernel in SVM?
#
# A Kernel is a **mathematical transformation** that converts data into a
# higher-dimensional space so that it becomes **linearly separable**.
#
# SVM does not separate data in original space.
# It first transforms the data, then applies a **linear separator**.
#
# ## 2️⃣ Why Kernels are Needed?
#
# Sometimes data is **not linearly separable** in 2D.
#
# Example:
# - Circular or curved data cannot be separated using a straight line.
#
#
# ## 3️⃣ Idea Behind Kernels
#
# Original Space → Transform → Higher Dimension → Linear Separation
#
# 2D Data → 3D Transformation → Flat Plane separates classes
#
# ## 4️⃣ Example – Circular Data
#
# 2D view:
# - Data is in circle form → Linear SVC fails.
#
# After kernel transformation:
# - Data becomes separable in 3D.
# - Linear SVC works in higher dimension.
#
#
# ## 5️⃣ Mathematical Concept
#
# Kernel performs a transformation:
#
# x → φ(x)
#
# This converts input into a new feature space.
#
#
# ## 6️⃣ 1D to 2D Example
#
# Original data:
# x
#
# Transformation:
# y = x²
#
# This makes curved data **linearly separable**.
#
#
# ## 7️⃣ Types of SVM Kernels
#
# 1. Polynomial Kernel
# 2. RBF Kernel
# 3. Sigmoid Kernel
#
#
# ## 8️⃣ Polynomial Kernel
#
# Used when data has polynomial relationship.
#
# K(x, y) = (xᵀy + c)ᵈ
#
#
# ## 9️⃣ RBF Kernel (Gaussian)
#
# Most popular kernel.
#
# Used when data is complex & nonlinear.
#
# K(x, y) = exp( −γ ||x − y||² )
#
#
# ## 🔟 Sigmoid Kernel
#
# Works like neural network activation.
#
# K(x, y) = tanh(αxᵀy + c)
#
#
# ## 📝 Summary
#
# - Kernel maps data into higher dimensions.
# - Makes nonlinear data linearly separable.
# - Common kernels: Polynomial, RBF, Sigmoid.
# - RBF is the most widely used kernel.
