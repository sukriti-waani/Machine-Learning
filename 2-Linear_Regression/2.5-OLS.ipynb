# %% [markdown]
# # 📘 Linear Regression using OLS
# (Ordinary Least Squares)
#
# ## 1️⃣ Linear Regression Model
#
# The simple linear regression model is:
#
# y = β₀ + β₁x + ε
#
# Where:
# - y   → dependent variable
# - x   → independent variable
# - β₀  → intercept
# - β₁  → slope (coefficient)
# - ε   → error term
#
# ## 2️⃣ Predicted Value
#
# The predicted output is:
#
# ŷ = β₀ + β₁x
#
#
# ## 3️⃣ Objective of OLS
#
# OLS finds the values of β₀ and β₁ such that the
# **sum of squared errors is minimum**.
#
#
# ## 4️⃣ Ordinary Least Squares Cost Function
#
# The OLS loss function is:
#
# S(β₀, β₁) = (1 / n) Σᵢ₌₁ⁿ ( yᵢ − β₀ − β₁xᵢ )²
#
# Where:
# - n → number of data points
#
# ## 5️⃣ Minimization of Cost Function
#
# To minimize S(β₀, β₁), take partial derivatives
# with respect to β₀ and β₁ and set them to zero.
#
#
# ## 6️⃣ Partial Derivative w.r.t β₀
#
# ∂S / ∂β₀ = −(2 / n) Σᵢ₌₁ⁿ ( yᵢ − β₀ − β₁xᵢ ) = 0
#
#
# ### Simplifying Equation (1)
#
# Σᵢ₌₁ⁿ yᵢ − nβ₀ − β₁ Σᵢ₌₁ⁿ xᵢ = 0
#
# ⇒ β₀ = ȳ − β₁x̄
#
# Where:
# - ȳ → mean of y
# - x̄ → mean of x
#
#
# ## 7️⃣ Partial Derivative w.r.t β₁
#
# ∂S / ∂β₁ = −(2 / n) Σᵢ₌₁ⁿ ( yᵢ − β₀ − β₁xᵢ ) xᵢ = 0
#
#
# ### Simplifying Equation (2)
#
# Σᵢ₌₁ⁿ xᵢyᵢ − β₀ Σᵢ₌₁ⁿ xᵢ − β₁ Σᵢ₌₁ⁿ xᵢ² = 0
#
#
# ## 8️⃣ Substituting β₀ = ȳ − β₁x̄
#
# After substitution and simplification:
#
# β₁ = Σᵢ₌₁ⁿ ( xᵢ − x̄ )( yᵢ − ȳ )
#       --------------------------------
#         Σᵢ₌₁ⁿ ( xᵢ − x̄ )²
#
#
# ## 9️⃣ Final OLS Estimates
#
# Slope (Coefficient):
#
# β₁ = Σ (xᵢ − x̄)(yᵢ − ȳ) / Σ (xᵢ − x̄)²
#
# Intercept:
#
# β₀ = ȳ − β₁x̄
#
#
# ## 🔟 Interpretation of OLS
#
# - β₁ represents change in y for one unit change in x
# - β₀ is value of y when x = 0
# - OLS gives a **closed-form solution**
# - No need for Gradient Descent
#
#
# ## 1️⃣1️⃣ Properties of OLS
#
# - Minimizes Mean Squared Error
# - Convex optimization problem
# - Single global minimum
# - Sensitive to outliers
#
#
# ## 1️⃣2️⃣ Summary
#
# - OLS minimizes sum of squared errors
# - Cost function uses squared residuals
# - β₁ depends on covariance of x and y
# - β₀ aligns regression line with data mean
# - OLS gives exact analytical solution
