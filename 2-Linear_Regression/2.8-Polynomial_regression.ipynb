# %% [markdown]
# # 📘 Polynomial Regression
#
# ## 1️⃣ Why Polynomial Regression?
#
# Simple Linear Regression:
#
# h(x) = β₀ + β₁x
#
# This works only when the relationship between x and y is **linear**.
#
# If the relationship is **non-linear**, the linear line gives high error.
#
# Polynomial Regression is used to handle **non-linear relationships**.
#
#
# ## 2️⃣ Polynomial Regression Model
#
# General polynomial equation of degree n:
#
# h(x) = β₀ + β₁x + β₂x² + β₃x³ + ... + βₙxⁿ
#
#
# ## 3️⃣ Polynomial Degrees
#
# Degree 0:
#
# h(x) = β₀
# (Constant line)
#
# Degree 1:
#
# h(x) = β₀ + β₁x
# (Simple Linear Regression)
#
# Degree 2:
#
# h(x) = β₀ + β₁x + β₂x²
#
# Degree n:
#
# h(x) = β₀ + β₁x + β₂x² + ... + βₙxⁿ
#
#
# ## 4️⃣ Effect of Degree
#
# - Small degree → underfitting
# - Large degree → overfitting
# - Correct degree → best curve fit
#
#
# ## 5️⃣ Polynomial Regression with Multiple Features
#
# For two independent features x₁ and x₂:
#
# Degree 1:
#
# h(x) = β₀ + β₁x₁ + β₂x₂
#
# Degree 2:
#
# h(x) = β₀ + β₁x₁ + β₂x₂ + β₃x₁² + β₄x₂²
#
#
# ## 6️⃣ Important Observation
#
# Although Polynomial Regression looks non-linear in x,
# it is **linear in parameters (β values)**.
#
# So it is still solved using **Linear Regression techniques**.
#
#
# ## 7️⃣ When to Use Polynomial Regression?
#
# - When data shows **curved or non-linear pattern**
# - When simple linear regression gives high error
#
#
# ## 8️⃣ Summary
#
# - Polynomial Regression handles non-linear data
# - Model: h(x) = β₀ + β₁x + β₂x² + ... + βₙxⁿ
# - Degree controls model complexity
# - High degree → overfitting
# - Low degree → underfitting
