# %% [markdown]
# # 📘 Regression Error Metrics: MSE, MAE, RMSE
#
# ## Basic Notation
#
# - yᵢ  → actual value
# - ŷᵢ  → predicted value
# - n   → number of data points
#
# Error (residual):
#
# eᵢ = yᵢ − ŷᵢ
#
#
# ## 1️⃣ Mean Squared Error (MSE)
#
# MSE is the **average of squared errors**.
#
# Formula:
#
# MSE = (1 / n) Σᵢ₌₁ⁿ ( yᵢ − ŷᵢ )²
#
#
# ### Explanation of MSE
#
# - Errors are **squared**
# - Large errors get **more penalty**
# - Always ≥ 0
#
#
# ### Properties of MSE
#
# - Differentiable
# - Convex cost function
# - Has one global minimum
# - Used as cost function in Linear Regression
#
#
# ### Advantages of MSE
#
# 1. Easy to optimize using Gradient Descent
# 2. Strong penalty for large errors
#
#
# ### Disadvantages of MSE
#
# 1. Not robust to outliers
# 2. Unit is squared (not interpretable)
#
#
# ## 2️⃣ Mean Absolute Error (MAE)
#
# MAE is the **average of absolute errors**.
#
# Formula:
#
# MAE = (1 / n) Σᵢ₌₁ⁿ | yᵢ − ŷᵢ |
#
#
# ### Explanation of MAE
#
# - Absolute difference only
# - No squaring
# - Treats all errors equally
#
# ### Properties of MAE
#
# - Robust to outliers
# - Same unit as output
# - Not differentiable at zero
#
# ### Advantages of MAE
#
# 1. Easy to interpret
# 2. Less sensitive to outliers
#
# ### Disadvantages of MAE
#
# 1. Optimization is harder
# 2. Slower convergence
#
#
#
# ## 3️⃣ Root Mean Squared Error (RMSE)
#
# RMSE is the **square root of MSE**.
#
# Formula:
#
# RMSE = √MSE
#      = √[ (1 / n) Σᵢ₌₁ⁿ ( yᵢ − ŷᵢ )² ]
#
#
# ### Explanation of RMSE
#
# - Penalizes large errors
# - Same unit as y
# - More interpretable than MSE
#
# ### Advantages of RMSE
#
# 1. Same unit as output
# 2. Differentiable
# 3. Widely used metric
#
# ### Disadvantages of RMSE
#
# 1. Sensitive to outliers
#
#
# ## 4️⃣ Comparison Table
#
# MSE:
# - Squares error
# - Sensitive to outliers
# - Unit²
#
# MAE:
# - Absolute error
# - Robust to outliers
# - Same unit as y
#
# RMSE:
# - √ of squared error
# - Sensitive to outliers
# - Same unit as y
#
#
# ## 5️⃣ When to Use Which?
#
# - Use **MSE** → model training
# - Use **MAE** → presence of outliers
# - Use **RMSE** → real-world error interpretation
#
# ## Summary
#
# - MSE penalizes large errors heavily
# - MAE is robust and interpretable
# - RMSE balances penalty and interpretability
# - RMSE is most commonly reported metric
