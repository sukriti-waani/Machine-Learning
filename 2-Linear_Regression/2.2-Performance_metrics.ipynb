# %% [markdown]
# # 📘 Performance Metrics in Linear Regression
#
# Performance metrics are used to **evaluate how well a regression model fits the data**.
#
# ## 1️⃣ R-squared (R²)
#
# R-squared measures how much **variance in the output (y)** is explained by the model.
#
# Formula:
#
# R² = 1 − (SS_res / SS_total)
#
#
# ### 1.1 Expanded Form of R²
#
# SS_res (Residual Sum of Squares):
#
# SS_res = Σ ( yᵢ − ŷᵢ )²
#
# SS_total (Total Sum of Squares):
#
# SS_total = Σ ( yᵢ − ȳ )²
#
# Where:
# - yᵢ → actual value
# - ŷᵢ → predicted value
# - ȳ → mean of actual values
#
#
# ### 1.2 Final R² Equation
#
# R² = 1 − [ Σ ( yᵢ − ŷᵢ )²  /  Σ ( yᵢ − ȳ )² ]
#
#
# ### 1.3 Interpretation of R²
#
# - R² = 0 → model explains nothing
# - R² = 1 → perfect model
# - R² = 0.70 → 70% variance explained
# - Higher R² → better fit
#
# Note:
# R² always **increases** when we add more features,
# even if those features are useless.
#
#
# ## 2️⃣ Problem with R-squared
#
# In Multiple Linear Regression:
#
# - Adding more features → R² increases
# - Even if the feature is irrelevant
#
# This can lead to **overfitting**.
#
# So R² alone is **not reliable** for multiple features.
#
#
# ## 3️⃣ Adjusted R-squared
#
# Adjusted R² fixes the limitation of R²
# by **penalizing unnecessary features**.
#
# Formula:
#
# Adjusted R² = 1 − [ (1 − R²)(N − 1) / (N − p − 1) ]
#
#
# ### 3.1 Terms in Adjusted R²
#
# - N → number of data points
# - p → number of independent features
# - R² → R-squared value
#
#
# ## 4️⃣ Interpretation of Adjusted R²
#
# - Adjusted R² **increases** only if the new feature improves the model
# - It can **decrease** if the feature is not useful
# - Best metric for **Multiple Linear Regression**
#
#
# ## 5️⃣ R² vs Adjusted R² (Comparison)
#
# R²:
# - Always increases
# - Can mislead in multiple features
#
# Adjusted R²:
# - Increases only when feature is useful
# - Penalizes complexity
# - More reliable
#
#
# ## 6️⃣ Summary
#
# - R² measures explained variance
# - Formula: R² = 1 − SS_res / SS_total
# - Problem: R² increases with more features
# - Adjusted R² solves this problem
# - Use Adjusted R² for Multiple Linear Regression
